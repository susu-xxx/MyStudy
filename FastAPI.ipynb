# %% [markdown]
# # 필요한 라이브러리 설치
# - fastapi : python 쪽에 요청을 처리할 수 있는 서버를 로드할 수 있는 라이브러리 (flask 라이브러리 유사)
# - uvicorn : 서버 재요청을 할 때마다, 서버를 껐다 켜는 게 불편하니까 사용하기 쉬우려고 추가하는 라이브러리

# %%
! pip install fastapi
# Out:
# Collecting fastapi
#   Downloading fastapi-0.115.14-py3-none-any.whl.metadata (27 kB)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\smhrd\anaconda3\lib\site-packages (from fastapi) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\smhrd\anaconda3\lib\site-packages (from fastapi) (4.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\smhrd\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\smhrd\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.20.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\smhrd\anaconda3\lib\site-packages (from starlette<0.47.0,>=0.40.0->fastapi) (4.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\smhrd\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\smhrd\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (1.3.0)
# Downloading fastapi-0.115.14-py3-none-any.whl (95 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
# Installing collected packages: starlette, fastapi
# Successfully installed fastapi-0.115.14 starlette-0.46.2

# %%
# !pip install uvicorn[standard]
# Out:
# Collecting uvicorn[standard]
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: click>=7.0 in c:\users\smhrd\anaconda3\lib\site-packages (from uvicorn[standard]) (8.1.7)
# Requirement already satisfied: h11>=0.8 in c:\users\smhrd\anaconda3\lib\site-packages (from uvicorn[standard]) (0.14.0)
# Requirement already satisfied: colorama>=0.4 in c:\users\smhrd\anaconda3\lib\site-packages (from uvicorn[standard]) (0.4.6)
# Collecting httptools>=0.6.3 (from uvicorn[standard])
#   Downloading httptools-0.6.4-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\smhrd\anaconda3\lib\site-packages (from uvicorn[standard]) (0.21.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\smhrd\anaconda3\lib\site-packages (from uvicorn[standard]) (6.0.1)
# Collecting watchfiles>=0.13 (from uvicorn[standard])
#   Downloading watchfiles-1.1.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard])
#   Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: anyio>=3.0.0 in c:\users\smhrd\anaconda3\lib\site-packages (from watchfiles>=0.13->uvicorn[standard]) (4.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\smhrd\anaconda3\lib\site-packages (from anyio>=3.0.0->watchfiles>=0.13->uvicorn[standard]) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\smhrd\anaconda3\lib\site-packages (from anyio>=3.0.0->watchfiles>=0.13->uvicorn[standard]) (1.3.0)
# Downloading httptools-0.6.4-cp312-cp312-win_amd64.whl (88 kB)
# Downloading watchfiles-1.1.0-cp312-cp312-win_amd64.whl (292 kB)
# Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Installing collected packages: websockets, httptools, watchfiles, uvicorn
# Successfully installed httptools-0.6.4 uvicorn-0.35.0 watchfiles-1.1.0 websockets-15.0.1

# %% [markdown]
# # FastAPI 사용하기

# %%
# 1. 라이브러리 가져오기
from fastapi import FastAPI

# %%
# !pip install nbconvert
# Out:
# Requirement already satisfied: nbconvert in c:\users\smhrd\anaconda3\lib\site-packages (7.16.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\smhrd\anaconda3\lib\site-packages (from nbconvert) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\smhrd\anaconda3\lib\site-packages (from nbconvert) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\smhrd\anaconda3\lib\site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\smhrd\anaconda3\lib\site-packages (from nbconvert) (3.1.4)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\smhrd\anaconda3\lib\site-packages (from nbconvert) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\smhrd\anaconda3\lib\site-packages (from nbconvert) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\smhrd\anaconda3\lib\site-packages (from nbconvert) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\smhrd\anaconda3\lib\site-packages (from nbconvert) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\smhrd\anaconda3\lib\site-packages (from nbconvert) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\smhrd\anaconda3\lib\site-packages (from nbconvert) (5.10.4)
# Requirement already satisfied: packaging in c:\users\smhrd\anaconda3\lib\site-packages (from nbconvert) (24.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\smhrd\anaconda3\lib\site-packages (from nbconvert) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\smhrd\anaconda3\lib\site-packages (from nbconvert) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\users\smhrd\anaconda3\lib\site-packages (from nbconvert) (1.2.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\smhrd\anaconda3\lib\site-packages (from nbconvert) (5.14.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\smhrd\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\smhrd\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert) (0.5.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\smhrd\anaconda3\lib\site-packages (from jupyter-core>=4.7->nbconvert) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\smhrd\anaconda3\lib\site-packages (from jupyter-core>=4.7->nbconvert) (305.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\smhrd\anaconda3\lib\site-packages (from nbclient>=0.5.0->nbconvert) (8.6.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\smhrd\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\smhrd\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert) (4.23.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\smhrd\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert) (2.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\smhrd\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\smhrd\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\smhrd\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\smhrd\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\smhrd\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\smhrd\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (25.1.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\smhrd\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (6.4.1)

# %%
# 2. FastAPI를 기반으로 한 app 생성
app= FastAPI()

# 3. 요청을 처리할 수 있는 url - 함수를 생성 
# 수집해ㅑ 하는 데이터가 있다면, 파라미터로 받아오면 된다.
@app.get("/temp")
def temp(data):
    1+1
    return "success"

# %%
# 동일출처 정책을 풀어줄 수 있는 설정을 잡아보자 
from fastapi.middleware.cors import CORSMiddleware

# %%
# app ==controller와 유사한 역할
# app에다가 미들웨어를 끼우는 작업 진행 --> 정책을 좀 풀어주려고!
app.add_middleware(
    #동일출처정책과 관련한 미들웨어
    CORSMiddleware,
    # 접근을 허용할 출처 (==접근을 허용할 url)
    allow_origins = [" http://localhost:8090"],
    allow_methods = ["*"],
    allow_headers = ["*"],
    allow_credentials = True
    
)

# %%
# 네이버에서 아이유 이미지 탭 첫번째 이미지 수집 

#1. 필요한 라이브러리 로딩 
from selenium import webdriver as wb
from selenium.webdriver.common.by import By

#2. 크롬창 띄우기 
def crawling(search) : 
    driver = wb.Chrome()
    url = f"https://search.naver.com/search.naver?where=image&sm=tab_jum&query={search_word}"
    driver.get(url)
    driver.implicitly_wait(5)
    
    #3. img 태그 선택해서 src 값 가져오기
    img = driver.find_element(By.CSS_SELECTOR, "#main_pack > section > div.api_subject_bx._fe_image_tab_grid_root.ani_fadein > div > div > div.image_tile._fe_image_tab_grid > div:nth-child(1) > div > div > div > img")
    img_src = img.get_attribute("src")
    
    #4.크롬 창 닫기
    driver.quit()
    
    return img_src
