# %% [markdown]
# #### 1. 문제 정의(목표)
# - 미국의 중심 도시인 보스턴의 1970년대 거주지에 대한 데이터를 바탕으로 주택 가격을 예측해보자

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### 2. 데이터 수집
# - 보스턴 집 값 데이터셋 로드

# %%
data = pd.read_csv('data/boston_house.csv')
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# ![image.png](attachment:e3ae13f5-aa86-4b56-8bf6-a51e89985d1e.png)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# ### 3. 데이터 전처리
# - 필요 없음

# %% [markdown]
# ### 4. 탐색적 데이터 분석

# %%
# 특성간 상관계수 출력
data.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# MEDV    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
plt.figure(figsize=(15,15))

# 상관계수 히트맵
sns.heatmap(data= data.corr(),
            annot = True, # annotation : 각 셀에 상관계수 값 출력 여부
            # 히트맵 색상
            cmap = 'Reds'
           )
# Out:
# <Axes: >

# %% [markdown]
# - 데이터로만 보았을 때, 주택가격(MEDV)과의 상관관계가 높은 특성은 RM(주택당 방 개수), LSTAT(소득하위계층 비율)

# %% [markdown]
# ### 5. 모델링(모델 선택, 학습, 평가)
# - 문제, 정답 데이터 설정
# - 학습, 평가 데이터 설정

# %%
# 먼저 문제, 정답으로 나눈 후, train_test_split으로 학습, 평가까지 분리

# %%
data.shape
# Out:
# (506, 14)

# %%
y = data['MEDV']
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
#  X = data.drop('MEDV', axis = 1)
# X = data.iloc[ :,:13]
X = data.loc[ :, : 'LSTAT']
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
# 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_size=0.3,
                                                    random_state=5)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (354, 13)
# (152, 13)
# (354,)
# (152,)

# %% [markdown]
# #### 선형회귀모델 적용

# %%
# 선형회귀모델 임포트
from sklearn.linear_model import LinearRegression

# 평가지표 MSE 임포트
from sklearn.metrics import mean_squared_error

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# w값 출력(특성 13개)
# y = w1x1 + w2x2 + w3x3 .. w13x13 + b
linear_model.coef_
# Out:
# array([-1.54486040e-01,  4.13948217e-02, -2.53765225e-02,  7.86055259e-01,
#        -1.29365836e+01,  4.03952301e+00, -1.05354914e-02, -1.33498644e+00,
#         3.18272501e-01, -1.26427463e-02, -9.77287564e-01,  1.26714702e-02,
#        -4.62052176e-01])

# %%
# 표기법 전환
np.set_printoptions(suppress = True, precision=4) # 지수표기법 억제, 소수점 4자리까지

# %%
linear_model.coef_
# Out:
# array([ -0.1545,   0.0414,  -0.0254,   0.7861, -12.9366,   4.0395,
#         -0.0105,  -1.335 ,   0.3183,  -0.0126,  -0.9773,   0.0127,
#         -0.4621])

# %%
# 데이터 프레임 생성
coef_df = pd.DataFrame({ # 데이터프레임 만든다
    'Feature' : X_train.columns, # 컬럼명은 Feature, 데이터는 X_train의 컬럼명으로 사용
    'Coefficient' : linear_model.coef_ # 컬럼명 : Coefficient, 데이터 : linear_model의 coef 사용
})
coef_df
# Out:
#     Feature  Coefficient
# 0      CRIM    -0.154486
# 1        ZN     0.041395
# 2     INDUS    -0.025377
# 3      CHAS     0.786055
# 4       NOX   -12.936584
# 5        RM     4.039523
# 6       AGE    -0.010535
# 7       DIS    -1.334986
# 8       RAD     0.318273
# 9       TAX    -0.012643
# 10  PTRATIO    -0.977288
# 11        B     0.012671
# 12    LSTAT    -0.462052

# %% [markdown]
# - 왜 RM과 LSTAT의 가중치가 가장 크지 않을까?
# - 독립변수에 들어가는 수치의 단위가 다르다! (스케일이 다름)
# - ex) NOX: 일산화질소 농도 -> 스케일이 매우 작음 -> 기울기를 크게
# - ex) Age의 경우 스케일이 크기 때문에 기울기를 작게

# %%
linear_model.intercept_
# Out:
# 31.73035129649775

# %% [markdown]
# MSE, RMSE 확인

# %%
# 예측값들 저장
pre_train = linear_model.predict(X_train)
pre_test = linear_model.predict(X_test)

# %%
pre_test
# Out:
# array([37.39  , 31.5679, 27.1337,  6.5512, 33.6931,  5.5492, 27.1001,
#        29.8298, 26.4462, 22.3887, 32.2474, 21.7489, 23.4237, 33.5797,
#        28.3145, 15.365 ,  0.1701, 18.7086, 14.6046, 10.8026,  3.1855,
#        19.3925, 38.3324, 24.4046, 31.9995, 11.352 , 24.9229, 23.3921,
#        22.7507, 21.0958, 16.123 ,  7.5354, 17.598 , 22.8221, 29.2679,
#        18.8053, 28.3367,  8.6047, 41.6323, 34.1975, 20.1177,  4.3099,
#        29.6111, 11.9215, 27.2222, 30.9454, -6.2647, 19.9637, 21.5938,
#        13.6436, 20.4985, 19.9377, 23.6538, 13.5165, 17.6443, 25.2014,
#        35.3149, 15.2534, 28.51  , 21.8525, 20.6639, 26.0316, 14.7163,
#        32.3465, 20.7126, 12.1691, 19.6099, 25.1948, 21.7899, 21.1727,
#        20.5707, 26.6823, 17.6343, 18.5968, 18.8646, 26.1126, 21.8839,
#        15.7936, 35.1229, 17.9301, 22.3741, 39.4321, 22.3586, 14.7508,
#        25.5997, 17.2634, 18.6474, 10.026 , 19.7358, 17.6831, 36.1822,
#        17.6844, 21.0208, 19.0402, 24.8101, 28.1227, 12.3997, 22.7785,
#        21.0432, 13.3715, 22.995 , 21.651 , 14.2948, 42.9844,  1.8887,
#        22.0456, 18.3099, 22.3247, 29.2639, 18.4094, 27.8731, 24.5829,
#        20.2883, 33.0103, 19.6981, 12.8886, 22.6587, 18.3919, 19.5948,
#        16.3862, 21.7491, 35.4807, 22.226 , 20.446 , 24.5924, 25.3763,
#        20.421 , 23.0493, 23.4528, 41.1019, 37.8471, 27.5238, 12.55  ,
#        16.1358, 18.2712, 21.6863, 15.7086,  5.6663, 24.0994, 30.5652,
#        23.0495, 18.1618, 16.1549, 21.7177, 35.068 , 23.2009, 30.2206,
#        18.2331, 22.2974, 29.3267, 13.6077, 31.6703])

# %%
train_mse = mean_squared_error(pre_train, y_train)
test_mse = mean_squared_error(pre_test,y_test)

print('train데이터 MSE :', train_mse)
print('test데이터 MSE :', test_mse)
# Out:
# train데이터 MSE : 19.068341850927226
# test데이터 MSE : 30.697037704088554

# %% [markdown]
# R2 Score 확인

# %% [markdown]
# ![image.png](attachment:5bc4aba0-e138-4854-80dc-dc6ac6baea18.png)

# %%
linear_model.score(X_train,y_train)
# Out:
# 0.7611598772034454

# %%
linear_model.score(X_test, y_test)

# R2 score
# 0.7 이상: 좋은 모델
# 0.5 이상: 조정 필요
# Out:
# 0.6771696999851695

# %% [markdown]
# #### 선형 회귀 모델 데이터 특성 확장
# - 선형회귀 모델은 데이터 분포가 직선의 형태를 많이 벗어나게 되면 예측 정확도가 낮아진다
# - 선형회귀 모델은 모델 튜닝을 위한 하이퍼파라미터가 존재하지 않음
# - 특성확장을 통해 성능을 높여보자

# %%
# copy : 기존의 데이터는 그대로 두면서, 복사하여 새로운 변수명에 넣어줌
# copy 없이 X_train을 새로운 변수에 담아준다면, 변수의 내용이 바뀔 경우 기존 X_train도 바뀔 수 있다.
extended_X_train = X_train.copy()

# %%
for col1 in X_train.columns: # 13번 반복
    for col2 in X_train.columns: # 13번 반복
        extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\983896645.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_train[col1+'x'+col2] = X_train[col1] * X_train[col2] # 169번 새로운 열 추가

# %%
extended_X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE      DIS  RAD  TAX  ...  \
# 445  10.67180   0.0  18.10     0  0.740  6.459  94.8   1.9879   24  666  ...
# 428   7.36711   0.0  18.10     0  0.679  6.193  78.1   1.9356   24  666  ...
# 481   5.70818   0.0  18.10     0  0.532  6.750  74.9   3.3317   24  666  ...
# 55    0.01311  90.0   1.22     0  0.403  7.249  21.9   8.6966    5  226  ...
# 488   0.15086   0.0  27.74     0  0.609  5.454  92.7   1.8209    4  711  ...
# ..        ...   ...    ...   ...    ...    ...   ...      ...  ...  ...  ...
# 486   5.69175   0.0  18.10     0  0.583  6.114  79.8   3.5459   24  666  ...
# 189   0.08370  45.0   3.44     0  0.437  7.185  38.9   4.5667    5  398  ...
# 495   0.17899   0.0   9.69     0  0.585  5.670  28.8   2.7986    6  391  ...
# 206   0.22969   0.0  10.59     0  0.489  6.326  52.5   4.3549    4  277  ...
# 355   0.10659  80.0   1.91     0  0.413  5.936  19.5  10.5857    4  334  ...
#
#      LSTATxCHAS  LSTATxNOX   LSTATxRM  LSTATxAGE  LSTATxDIS  LSTATxRAD  \
# 445         0.0   17.74520  154.88682   2273.304  47.669842     575.52
# 428         0.0   14.61208  133.27336   1680.712  41.654112     516.48
# 481         0.0    4.11768   52.24500    579.726  25.787358     185.76
# 55          0.0    1.93843   34.86769    105.339  41.830646      24.05
# 488         0.0   10.99854   98.49924   1674.162  32.885454      72.24
# ..          ...        ...        ...        ...        ...        ...
# 486         0.0    8.73334   91.58772   1195.404  53.117582     359.52
# 189         0.0    2.35543   38.72715    209.671  24.614513      26.95
# 495         0.0   10.29600   99.79200    506.880  49.255360     105.60
# 206         0.0    5.36433   69.39622    575.925  47.773253      43.88
# 355         0.0    2.30041   33.06352    108.615  58.962349      22.28
#
#      LSTATxTAX  LSTATxPTRATIO    LSTATxB  LSTATxLSTAT
# 445   15970.68        484.396  1032.5788     575.0404
# 428   14332.32        434.704  2081.6296     463.1104
# 481    5154.84        156.348  3042.3618      59.9076
# 55     1087.06         86.099  1904.4233      23.1361
# 488   12840.66        363.006  7135.3254     326.1636
# ..         ...            ...        ...          ...
# 486    9976.68        302.596  5882.3464     224.4004
# 189    2145.22         81.928  2139.2910      29.0521
# 495    6881.60        337.920  6921.9040     309.7600
# 206    3038.69        204.042  4331.7239     120.3409
# 355    1860.38        122.540  2094.5428      31.0249
#
# [354 rows x 182 columns]

# %%
extended_X_test = X_test.copy()

# %%
for col1 in X_test.columns: # 13번 반복
    for col2 in X_test.columns: # 13번 반복
        extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20004\3401772951.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   extended_X_test[col1+'x'+col2] = X_test[col1] * X_test[col2] # 169번 새로운 열 추가

# %%
extended_X_test
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  ...  \
# 226   0.38214   0.0   6.20     0  0.504  8.040   86.5  3.2157    8  307  ...
# 292   0.03615  80.0   4.95     0  0.411  6.630   23.4  5.1167    4  245  ...
# 90    0.04684   0.0   3.41     0  0.489  6.417   66.1  3.0923    2  270  ...
# 373  11.10810   0.0  18.10     0  0.668  4.906  100.0  1.1742   24  666  ...
# 273   0.22188  20.0   6.96     1  0.464  7.691   51.8  4.3665    3  223  ...
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...  ...
# 60    0.14932  25.0   5.13     0  0.453  5.741   66.2  7.2254    8  284  ...
# 108   0.12802   0.0   8.56     0  0.520  6.474   97.1  2.4329    5  384  ...
# 298   0.06466  70.0   2.24     0  0.400  6.345   20.1  7.8278    5  358  ...
# 138   0.24980   0.0  21.89     0  0.624  5.857   98.2  1.6686    4  437  ...
# 370   6.53876   0.0  18.10     1  0.631  7.016   97.5  1.2024   24  666  ...
#
#      LSTATxCHAS  LSTATxNOX   LSTATxRM  LSTATxAGE  LSTATxDIS  LSTATxRAD  \
# 226        0.00    1.57752   25.16520    270.745  10.065141      25.04
# 292        0.00    1.93170   31.16100    109.980  24.048490      18.80
# 90         0.00    4.30809   56.53377    582.341  27.243163      17.62
# 373        0.00   23.22636  170.58162   3477.000  40.826934     834.48
# 273        6.58    3.05312   50.60678    340.844  28.731570      19.74
# ..          ...        ...        ...        ...        ...        ...
# 60         0.00    5.95695   75.49415    870.530  95.014010     105.20
# 108        0.00    6.38040   79.43598   1191.417  29.851683      61.35
# 298        0.00    1.98800   31.53465     99.897  38.904166      24.85
# 138        0.00   13.30368  124.87124   2093.624  35.574552      85.28
# 370        2.96    1.86776   20.76736    288.600   3.559104      71.04
#
#      LSTATxTAX  LSTATxPTRATIO     LSTATxB  LSTATxLSTAT
# 226     960.91         54.462   1212.4994       9.7969
# 292    1151.50         90.240   1865.4300      22.0900
# 90     2378.70        156.818   3455.1058      77.6161
# 373   23156.82        702.354  13800.2130    1208.9529
# 273    1467.34        122.388   2571.2666      43.2964
# ..         ...            ...         ...          ...
# 60     3734.60        259.055   5195.6965     172.9225
# 108    4711.68        256.443   4849.5948     150.5529
# 298    1779.26         73.556   1830.1528      24.7009
# 138    9316.84        451.984   8358.2928     454.5424
# 370    1971.36         59.792   1160.4680       8.7616
#
# [152 rows x 182 columns]

# %%
# 특성 확장된 train 데이터로 학습
linear_model2 = LinearRegression()
linear_model2.fit(extended_X_train,y_train)
# Out:
# LinearRegression()

# %%
linear_model2.score(extended_X_train,y_train) # 특성 확장전 : 0.76
# Out:
# 0.9332471683804472

# %%
linear_model2.score(extended_X_test,y_test) # 특성 확장 전 : 0.67
# Out:
# 0.8093536759487533

# %% [markdown]
# 라쏘(Lasso) 모델 적용

# %%
from sklearn.linear_model import Lasso

# %%
# alpha 값이 높아지면, 규제가 강해지면서 과대적합이 줄어듬, 오차는 커질 수 있음
lasso_model = Lasso() # 알파의 default값 : 1

# %%
lasso_model.fit(extended_X_train, y_train)
# Out:
# C:\Users\smhrd1\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.900e+03, tolerance: 2.826e+00
#   model = cd_fast.enet_coordinate_descent(
# Lasso()

# %%
sum(lasso_model.coef_ !=0)
# 182개의 특성 중 94개의 특성이 남았다
# Out:
# 94

# %%
lasso_model.score(extended_X_train, y_train) # 선형회귀 0.93
# Out:
# 0.8804239058511475

# %%
lasso_model.score(extended_X_test,y_test) # 선형 회귀 0.81
# Out:
# 0.8390880939300641

# %% [markdown]
# - train에서 r2는 내려갔지만, test에서는 오름
# - 선형회귀 모델에 비해, 과대적합이 줄어든 것을 확인할 수 있다.

# %% [markdown]
# #### 릿지(Ridge) 모델 적용

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha= 1)

# %%
ridge_model.fit(extended_X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
ridge_model.score(extended_X_train,y_train) # 라쏘 0.88
# Out:
# 0.9290610763449758

# %%
ridge_model.score(extended_X_test,y_test) # 라쏘 0.84
# Out:
# 0.8125837987008401

# %% [markdown]
# - alpha값이 1일때, 릿지 모델에 비해 라쏘모델이 과대적합 해소에는 더 적합하다

# %% [markdown]
# #### 하이퍼파라미터 튜닝
# - alpha 값을 바꿔가며 RMSE를 확인

# %%
# Lasso 모델
# alpha값에 따라 RMSE 계산값을 빈 리스트에 담아주기
alpha_list = [0.0001,0.01,0.1,1,10,100]
lasso_train_list = []
lasso_test_list = []

for i in alpha_list:
    # alpha값을 변경하며 라쏘 모델을 불러오기
    lasso_model = Lasso(alpha = i)
    lasso_model.fit(extended_X_train,y_train)

    # 예측값 구하기
    lasso_train_pre = lasso_model.predict(extended_X_train)
    # 예측값과 정답(실제값)을 이용해서 RMSE 추출
    lasso_train_RMSE = mean_squared_error(lasso_train_pre,y_train)**0.5
    # 빈 리스트에 RMSE값 넣기
    lasso_train_list.append(lasso_train_RMSE)

    # test
    lasso_test_pre = lasso_model.predict(extended_X_test)
    # 예측값과 정답(실제값)을 이용해서 RMSE 추출
    lasso_test_RMSE = mean_squared_error(lasso_test_pre,y_test)**0.5
    # 빈 리스트에 RMSE값 넣기
    lasso_test_list.append(lasso_test_RMSE)
# Out:
# C:\Users\smhrd1\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.109e+03, tolerance: 2.826e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\smhrd1\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.251e+03, tolerance: 2.826e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\smhrd1\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.541e+03, tolerance: 2.826e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\smhrd1\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.900e+03, tolerance: 2.826e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\smhrd1\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.190e+03, tolerance: 2.826e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\smhrd1\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.334e+00, tolerance: 2.826e+00
#   model = cd_fast.enet_coordinate_descent(

# %%
lasso_train_pre
# Out:
# array([11.0293, 14.2716, 25.4736, 34.2802, 13.4003, 24.9312, 30.6235,
#        30.9279, 12.174 , 31.2091, 12.2345, 34.5266, 26.9636, 19.7661,
#        16.4702, 12.6295, 30.403 , 17.952 , 23.8314, 20.9182, 13.0601,
#        22.0038, 11.4303, 20.4243, 20.7321, 32.1195, 20.6153, 15.4508,
#        31.1096, 37.5604, 25.1437, 25.5598, 18.5866, 16.3877, 34.7931,
#        25.1975, 33.6382, 24.6353, 19.9772, 17.7993, 23.0245, 20.3931,
#        28.5713, 15.6272, 24.491 , 25.7843, 22.629 , 23.5834, 31.5317,
#        17.6756, 29.6767, 28.177 , 12.3042, 32.1944, 27.5388, 19.0967,
#        34.7067, 11.2305, 24.039 , 26.4183, 22.56  , 18.6936, 21.7544,
#        25.8123, 19.2352, 32.0278, 22.5917, 19.6569,  7.5842,  5.8788,
#        22.6408, 19.7771, 21.7512, 20.8684, 17.465 , 31.2748, 37.9148,
#        18.3167, 16.0481, 26.114 , 16.4292, 25.526 , 18.3601, 24.187 ,
#        15.0164, 23.4664, 13.2369, 21.7464, 27.1086, 22.7423, 17.7284,
#        14.291 , 20.877 , 38.5941, 20.4   , 13.9405, 18.1693, 24.0633,
#        16.8553, 23.1626, 25.4849, 15.9738, 30.4032, 18.9493, 18.0138,
#        22.0301, 33.1053, 25.5694, 26.7687, 28.097 , 31.2521, 25.363 ,
#        22.9543, 21.7675, 35.3932, 18.26  , 31.2433, 27.8354, 14.6455,
#        34.8354, 22.254 , 14.2481, 15.0605, 12.7537, 29.2058, 14.9292,
#        17.7731, 27.6101, 30.767 , 29.0271, 20.2717, 11.4099, 27.8152,
#        25.1212, 22.9305, 27.5164, 25.2041, 26.0097, 24.1248, 18.2001,
#        18.3087, 13.6648, 21.4111, 24.9146, 12.7205, 33.9359, 35.9842,
#        17.6729, 10.2246, 32.5714, 26.7776, 20.1618, 25.1451, 23.8975,
#        21.8686, 18.5566, 24.9527, 36.3613, 21.705 , 20.1215, 20.4494,
#        21.1454, 21.5359, 32.5341, 14.5016, 18.4054, 14.5066, 30.6687,
#        44.7808, 22.9785, 24.235 ,  7.5632, 32.8282, 19.296 , 19.1878,
#        23.7685, 22.6973,  7.2218, 16.855 , 13.0328, 15.2405, 16.526 ,
#        21.8908, 37.9401, 31.7393, 20.0084, 13.8415, 39.3354, 22.0148,
#        15.4989, 18.9117, 18.8836, 34.2211, 31.3931, 22.608 , 17.2962,
#        24.0717, 25.4966, 20.0602, 27.5649, 11.7428, 32.7153, 24.851 ,
#        15.3811, 24.9513, 21.9033, 27.8269, 25.4864, 35.8017, 29.171 ,
#        19.3546, 16.8435, 21.1761, 27.6815, 25.4218, 27.6191, 29.2277,
#        19.9599, 13.8775, 27.6273, 24.3008, 28.012 , 32.3318, 18.8566,
#        22.7984, 24.747 , 18.0512, 39.2678, 21.369 , 23.3742, 21.8872,
#        26.1139, 30.8334, 19.7027, 26.2645, 36.015 , 36.7602,  7.0968,
#        17.1677, 23.2722, 16.6963, 26.9223, 36.2196, 27.461 , 14.6527,
#        15.0956, 18.53  ,  6.2384, 23.8464, 11.2378, 30.6902,  4.0717,
#         9.315 , 21.5456, 23.7983, 14.2403, 18.6304, 37.7844, 24.3882,
#        -2.1964, 16.0353, 12.8455, 31.5501, 27.8389, 13.8126, 23.4289,
#        32.0739, 23.4606, 27.8791, 19.0433, 19.7538, 24.1023, 21.7436,
#        17.8296, 31.6346, 27.6123, 26.9858, 13.0666, 20.4808, 19.741 ,
#        26.888 ,  3.8989, 30.2394, 11.5328, 19.0545, 41.5677, 30.3728,
#        15.1625, 18.832 , 35.5545, 18.2862, 16.6754, 13.2754, 30.3529,
#        31.9086, 11.6216, 17.073 , 23.4336, 25.4694, 36.7407, 26.2458,
#        20.5359, 33.1599, 21.08  , 22.8794, 20.4115,  5.7338, 37.5834,
#        25.1766, 26.6717, 20.5688, 11.5738, 19.2049, 19.2651,  6.4371,
#        21.1518, 30.4048, 20.6581, 18.6685, 19.3315, 24.6357, 19.7478,
#        21.7755, 22.8634, 15.4568, 13.6543, 13.7049, 29.6664, 42.5214,
#        22.9938, 24.0735, 17.3053, 28.0642,  9.0534, 19.4705, 11.1952,
#        43.6841, 20.2728, 21.0654, 26.6366, 19.3835, 12.0997, 18.9863,
#        32.2142, 36.0029, 13.37  , 24.3437, 10.2049, 19.9919, 18.0019,
#        33.2575, 18.281 , 23.7554, 18.8861])

# %%
# 한글을 쓰기 위한 rc import
from matplotlib import rc
rc('font', family = 'Malgun Gothic')

# %%
plt.figure(figsize=(10,5))
plt.plot(lasso_train_list, label='train') # train 그래프
plt.plot(lasso_test_list,label='test') # test 그래프
plt.title('Lasso모델 : alpha - RMSE 그래프') # 그래프 제목
plt.xlabel('alpha값')
plt.xticks(np.arange(6), alpha_list) # x축 tick값(x축 값 개수, 실제 들어갈 값)
plt.ylabel('RMSE') # Y축 라벨
plt.legend()
plt.grid()
plt.show()

# %%
# Ridge 모델
# alpha값에 따라 RMSE 계산값을 빈 리스트에 담아주기
alpha_list = [0.0001,0.01,0.1,1,10,100]
ridge_train_list = []
ridge_test_list = []

for i in alpha_list:
    # alpha값을 변경하며 라쏘 모델을 불러오기
    ridge_model = Ridge(alpha = i)
    ridge_model.fit(extended_X_train,y_train)

    # 예측값 구하기
    ridge_train_pre = ridge_model.predict(extended_X_train)
    # 예측값과 정답(실제값)을 이용해서 RMSE 추출
    ridge_train_RMSE = mean_squared_error(ridge_train_pre,y_train)**0.5
    # 빈 리스트에 RMSE값 넣기
    ridge_train_list.append(ridge_train_RMSE)

    # test
    ridge_test_pre = ridge_model.predict(extended_X_test)
    # 예측값과 정답(실제값)을 이용해서 RMSE 추출
    ridge_test_RMSE = mean_squared_error(ridge_test_pre,y_test)**0.5
    # 빈 리스트에 RMSE값 넣기
    ridge_test_list.append(ridge_test_RMSE)

# %%
plt.figure(figsize=(10,5))
plt.plot(ridge_train_list, label='train') # train 그래프
plt.plot(ridge_test_list,label='test') # test 그래프
plt.title('ridge모델 : alpha - RMSE 그래프') # 그래프 제목
plt.xlabel('alpha값')
plt.xticks(np.arange(6), alpha_list) # x축 tick값(x축 값 개수, 실제 들어갈 값)
plt.ylabel('RMSE') # Y축 라벨
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# - Lasso 모델과 Ridge 모델 모두 alpha값이 10일때 가장 과대적합 제어에 유리한 것을 볼 수 있음
# - Lasso 모델은 Ridge모델에 비해, 과대적합 제어가 더 잘된것을 확인
# - 과대적합 제어를 위해서는 Lasso를 사용하는 것이 유리하다.
# - 그러나 규제의 정도에 따라 Lasso모델은 오차값이 급격하게 증가함을 확인
# - 모델의 정확한 예측(r2 score)면에서는 Ridge모델이 더 유리하다.
